# %% [markdown]
# # データの取得と前処理

# %%
import pandas as pd
import datetime

# %%
from sqlalchemy import create_engine
url = "mysql+mysqldb://automatching:reiwa@localhost/auto_matching?charset=utf8mb4"
engine = create_engine(url)

# %%
query = """
select
  id, title, name, age, post_at, prefecture, city, site, genre
from posts
limit 10000;
"""

df = pd.read_sql(query, engine, index_col="id")

# %%
len(df)
# Out:
# 2357

# %%
df.head(3)
# Out:
#                                     title name     age           post_at  \
# id
# 11161514            エッチとアロママッサージで癒されませんか？   ゆう   40代前半       01/03 20:56
# 136516326  細身天然爆乳性転換ﾆｭｰﾊｰﾌ､ﾌｪﾗ騎乗位ﾊﾟｲｽﾞﾘ得意  まなみ   20代半ば  2019/12/28 23:59
# 136529291                    今からお会いできますか？  ゆうき   20代後半  2019/12/28 13:57
#
#           prefecture    city     site         genre
# id
# 11161514        神奈川県     藤沢市  ハッピーメール  ﾐﾄﾞﾙｴｲｼﾞ/ｼﾆｱ
# 136516326       神奈川県  横浜市瀬谷区  ワクワクメール        ミドルエイジ
# 136529291       神奈川県    茅ヶ崎市  ワクワクメール        ミドルエイジ

# %%
happymail_df = df.query('site == "ハッピーメール"')
wakuwaku_df = df.query('site == "ワクワクメール"')
pcmax_df = df.query('site == "PCMAX"')
ikukuru_df = df.query('site == "イククル"')

# %%
ikukuru_df
# Out:
#                                                                title name  \
# id
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...           スレンダー爆乳   美咲
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...   メスイキに興味ある人いますか？   まい
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...             お正月休み  さとみ
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...          セックスレスな人   晴美
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...             どなたでも   かな
# ...                                                              ...  ...
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...   明日日暮里で会えるかた～～＾＾   あや
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  これから多摩市鶴牧周辺で会える人   美咲
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...              優しい方  ローズ
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...    1月11日 浜松駅周辺 ご飯   ひな
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...        これから車内で！nh   美玲
#
#                                                     age           post_at  \
# id
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...  27歳  2019/12/31 23:30
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...  29歳  2019/12/31 23:08
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...  39歳       01/01 16:14
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...  22歳       01/01 11:39
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...  24歳       01/01 21:55
# ...                                                 ...               ...
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  32歳       01/02 19:31
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  29歳       01/02 18:41
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  48歳       01/02 22:54
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  19歳       01/02 22:45
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  29歳       01/03 20:16
#
#                                                    prefecture   city  site  \
# id
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...       神奈川県     東京  イククル
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...       神奈川県  横浜市西区  イククル
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...       神奈川県  横浜市中区  イククル
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...        東京都   千代田区  イククル
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...        東京都    足立区  イククル
# ...                                                       ...    ...   ...
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...        東京都     埼玉  イククル
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...        東京都    多摩市  イククル
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...       神奈川県   茅ヶ崎市  イククル
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...        東京都    新宿区  イククル
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...       神奈川県  横浜市中区  イククル
#
#                                                          genre
# id
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...       既婚者希望
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3lMUDNOQlhEMkJTSHp...       既婚者希望
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...       既婚者希望
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...       既婚者希望
# d1QzL0V6YTA0ZU1DN2lYbkN4S05uU3ludllBWmF6L0czNDB...       既婚者希望
# ...                                                        ...
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  ヒミツＨ!秘密だよ!
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  ヒミツＨ!秘密だよ!
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  ヒミツＨ!秘密だよ!
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  ヒミツＨ!秘密だよ!
# TVJRZFJYdXU5dU04a0RKQ0dQR3ZROS9XR2VwU0pPU3VjVnV...  ヒミツＨ!秘密だよ!
#
# [636 rows x 8 columns]
